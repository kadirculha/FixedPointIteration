# %%
def fixed_point_iteration(g, x_0, tol, max_iter):
    x_n = x_0
    iterations = 0
    data = []

    while iterations < max_iter:
        x_next = g(x_n)
        data.append((x_n, g(x_n)))

        if abs(x_next - x_n) < tol:
            break

        x_n = x_next
        iterations += 1

    return {
        "root": x_n,
        "iterations": iterations,
        "data": data
    }

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sabit nokta iterasyon fonksiyonu
def fixed_point_iteration(g, x_0, tol, max_iter):
    x_n = x_0
    iterations = 0
    data = []

    while iterations < max_iter:
        x_next = g(x_n)
        data.append((x_n, g(x_n)))

        if abs(x_next - x_n) < tol:
            break

        x_n = x_next
        iterations += 1

    return {
        "root": x_n,
        "iterations": iterations,
        "data": data
    }

# Denklem: g(x) = cos(x)
def g(x):
    return np.cos(x)

# Başlangıç değeri ve tolerans
x_0 = 0.5
tolerance = 1e-5
max_iterations = 100

# Sabit nokta iterasyonunu uygula
result = fixed_point_iteration(g, x_0, tolerance, max_iterations)

# Grafik çizimi
x_values = np.linspace(-2, 2, 100)
y_values = g(x_values)

plt.plot(x_values, y_values, label='g(x) = cos(x)')
plt.scatter(*zip(*result['data']), color='red', label='Iterasyon Noktaları')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--', label='x ekseni')
plt.axvline(result['root'], color='green', linewidth=2, linestyle='--', label='Bulunan Sabit Nokta')
plt.title('Sabit Nokta Iterasyonu')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sabit nokta iterasyon fonksiyonu
def fixed_point_iteration(g, x_0, tol, max_iter):
    x_n = x_0
    iterations = 0
    data = []

    while iterations < max_iter:
        x_next = g(x_n)
        data.append((x_n, x_next))

        if abs(x_next - x_n) < tol:
            break

        x_n = x_next
        iterations += 1

    return {
        "root": x_n,
        "iterations": iterations,
        "data": data
    }

# Denklem: g(x) = cos(x)
def g(x):
    return np.cos(x)

# Başlangıç değeri ve tolerans
x_0 = 0.5
tolerance = 1e-5
max_iterations = 100

# Sabit nokta iterasyonunu uygula
result = fixed_point_iteration(g, x_0, tolerance, max_iterations)

# Grafik çizimi
iterations = range(len(result['data']))
x_values = [point[0] for point in result['data']]
y_values = [point[1] for point in result['data']]

plt.plot(iterations, y_values, marker='o', linestyle='-', color='b')
plt.title('Sabit Nokta Iterasyonu - Dönüş Değerleri')
plt.xlabel('Iterasyon Sayısı')
plt.ylabel('g(x_n)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sabit nokta iterasyon fonksiyonu
def fixed_point_iteration(g, x_0, tol, max_iter):
    x_n = x_0
    iterations = 0
    data = []

    while iterations < max_iter:
        x_next = g(x_n)
        data.append((x_n, x_next))

        if abs(x_next - x_n) < tol:
            break

        x_n = x_next
        iterations += 1

    return {
        "root": x_n,
        "iterations": iterations,
        "data": data
    }

# Denklem: g(x) = cos(x)
def g(x):
    return np.cos(x)

# Başlangıç değeri ve tolerans
x_0 = 0.5
tolerance = 1e-5
max_iterations = 100

# Sabit nokta iterasyonunu uygula
result = fixed_point_iteration(g, x_0, tolerance, max_iterations)

# Dönüş Değerleri Grafiği
iterations = range(len(result['data']))
x_values = [point[0] for point in result['data']]
y_values = [point[1] for point in result['data']]

plt.figure(figsize=(12, 4))

plt.subplot(131)
plt.plot(iterations, y_values, marker='o', linestyle='-', color='b')
plt.title('Dönüş Değerleri Grafiği')
plt.xlabel('Iterasyon Sayısı')
plt.ylabel('g(x_n)')

# Hata Grafiği
errors = [abs(point[1] - point[0]) for point in result['data']]

plt.subplot(132)
plt.plot(iterations, errors, marker='o', linestyle='-', color='r')
plt.title('Hata Grafiği')
plt.xlabel('Iterasyon Sayısı')
plt.ylabel('|x_{n+1} - x_n|')

# İterasyon Noktaları Grafiği
plt.subplot(133)
x_values = np.linspace(-2, 2, 100)
y_values = g(x_values)

plt.plot(x_values, y_values, label='g(x) = cos(x)')
plt.scatter(*zip(*result['data']), color='red', label='Iterasyon Noktaları')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--', label='x ekseni')
plt.axvline(result['root'], color='green', linewidth=2, linestyle='--', label='Bulunan Sabit Nokta')
plt.title('İterasyon Noktaları Grafiği')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sabit nokta iterasyon fonksiyonu
def fixed_point_iteration(g, x_0, tol, max_iter):
    x_n = x_0
    iterations = 0
    data = []

    while iterations < max_iter:
        x_next = g(x_n)
        data.append((x_n, x_next))

        if abs(x_next - x_n) < tol:
            break

        x_n = x_next
        iterations += 1

    return {
        "root": x_n,
        "iterations": iterations,
        "data": data
    }

# Denklem: g(x) = cos(x)
def g(x):
    return np.cos(x)

# Başlangıç değeri ve tolerans
x_0 = 0.5
tolerance = 1e-5
max_iterations = 100

# Sabit nokta iterasyonunu uygula
result = fixed_point_iteration(g, x_0, tolerance, max_iterations)

# Grafik çizimi
iterations = range(len(result['data']))
x_values = [point[0] for point in result['data']]
y_values = [point[1] for point in result['data']]
errors = [abs(point[1] - point[0]) for point in result['data']]

plt.figure(figsize=(15, 4))

# Dönüş Değerleri Grafiği
plt.subplot(131)
plt.plot(iterations, y_values, marker='o', linestyle='-', color='b')
plt.title('Dönüş Değerleri Grafiği')
plt.xlabel('Iterasyon Sayısı')
plt.ylabel('g(x_n)')

# Hata Grafiği
plt.subplot(132)
plt.plot(iterations, errors, marker='o', linestyle='-', color='r')
plt.title('Hata Grafiği')
plt.xlabel('Iterasyon Sayısı')
plt.ylabel('|x_{n+1} - x_n|')

# İterasyon Noktaları Grafiği
plt.subplot(133)
x_values_func = np.linspace(-2, 2, 100)
y_values_func = g(x_values_func)

plt.plot(x_values_func, y_values_func, label='g(x) = cos(x)')
plt.scatter(*zip(*result['data']), color='red', label='Iterasyon Noktaları')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--', label='x ekseni')
plt.axvline(result['root'], color='green', linewidth=2, linestyle='--', label='Bulunan Sabit Nokta')
plt.title('İterasyon Noktaları Grafiği')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Test senaryosu
def main():
    # Örnek bir g(x) fonksiyonu (x^2 - 4)
    g_function = lambda x: x**2 - 4

    # Başlangıç değeri ve tolerans belirle
    x_0 = 2.0
    tolerance = 0.001
    max_iterations = 2

    # Fixed-Point Iteration fonksiyonunu çağır
    result = fixed_point_iteration(g_function, x_0, tolerance, max_iterations)

    # Sonuçları yazdır
    print("Root:", result["root"])
    print("Iterations:", result["iterations"])
    print("Data:", result["data"])

if __name__ == "__main__":
    main()
# Out:
# Root: -4.0
# Iterations: 2
# Data: [(2.0, 0.0), (0.0, -4.0)]

# %%
import matplotlib.pyplot as plt

def fixed_point_iteration(g, x_0, tol, max_iter):
    x_n = x_0
    iterations = 0
    data = []

    while iterations < max_iter:
        x_next = g(x_n)
        data.append((x_n, g(x_n)))

        if abs(x_next - x_n) < tol:
            break

        x_n = x_next
        iterations += 1

    return {
        "root": x_n,
        "iterations": iterations,
        "data": data
    }

def main():
    # Örnek bir g(x) fonksiyonu (x^2 - 4)
    g_function = lambda x: x**4 - 4

    # Başlangıç değeri ve tolerans belirle
    x_0 = -1.6
    tolerance = 1e-6  # Örnek bir tolerans değeri
    max_iterations = 2  # Artırıldı for daha iyi bir grafik görmek için

    # Fixed-Point Iteration fonksiyonunu çağır
    result = fixed_point_iteration(g_function, x_0, tolerance, max_iterations)

    # Sonuçları yazdır
    print("Root:", result["root"])
    print("Iterations:", result["iterations"])
    print("Data:", result["data"])

    # Grafik çizimi
    x_vals, y_vals = zip(*result['data'])
    plt.plot(x_vals, y_vals, marker='o', label='Iterative Process')
    plt.axhline(0, color='black', linestyle='--', label='y=0')
    plt.axvline(result['root'], color='red', linestyle='--', label='Root')
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title('Fixed-Point Iteration Method')
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Root: 38.52178416045924
# Iterations: 2
# Data: [(-1.6, 2.553600000000001), (2.553600000000001, 38.52178416045924)]

# %%
import requests

api_url = "http://localhost:8008/fixed-point-iteration"
payload = {
    "function": "x**4 - 4",
    "initial_guess": -1.6,
    "tolerance": 1e-6,
    "max_iterations": 3,
}

response = requests.post(api_url, json=payload)
print(response.status_code)
# Out:
# 200

# %%
response.text
# Out:
# '{"data":[[-1.6,2.553600000000001],[2.553600000000001,38.52178416045924],[38.52178416045924,2202037.87856298]],"iterations":3,"root":2202037.87856298}\n'
